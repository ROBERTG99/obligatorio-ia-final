# %%
# !cd descent_env/

# %%
# %pip install numpy matplotlib seaborn psutil scikit-learn

# %%
import psutil
import os
import sys

# %%
# Importaciones principales
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle
import time
import random
from typing import Dict, List, Tuple, Any, Optional
from concurrent.futures import ProcessPoolExecutor, as_completed
from contextlib import redirect_stderr, redirect_stdout
import warnings
warnings.filterwarnings('ignore')

# Configurar matplotlib para Colab
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("✅ Importaciones completadas")
# Out:
# ✅ Importaciones completadas

# %%
# !cd "descent-env"

# 2. Instalar BlueSky + dependencias
# !pip install bluesky-simulator
# !pip install bluesky-gym
# !pip install pygame

# 3. Verificar instalación
# !python -c "import bluesky; print('BlueSky OK')"
# !python -c "from descent_env import DescentEnv; print('DescentEnv OK')"
# Out:
# /bin/bash: line 1: cd: descent-env: No such file or directory
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.4/698.4 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 39.5 MB/s eta 0:00:00
# ...
#   Created wheel for zmq: filename=zmq-0.0.0-py3-none-any.whl size=1265 sha256=8ccc1e8be827b06d722d76e37e9297c057137a8fbcc8feff6b4241baa7f3785a
#   Stored in directory: /root/.cache/pip/wheels/16/9e/c7/d497825227491fa00cca08b88ae37f9bcc14809233db76342c
# Successfully built zmq
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...

# %%
# !python descent_env/flan_qlearning_solution.py
# Out:
# python3: can't open file '/content/descent_env/flan_qlearning_solution.py': [Errno 2] No such file or directory

# %%
# !python descent_env/flan_qlearning_mega.py
# Out:
# 🚀 CONFIGURACIÓN OPTIMIZADA: Priorizando DescentEnv real para máximo rendimiento
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2025-07-04 15:18:21.041005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751642301.068634  202971 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751642301.076098  202971 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# prompt: open flan_results.png

from IPython.display import Image, display
display(Image('flan_results.png'))

# %%
# !python ejecutar_analisis.py
# Out:
# 🎯 EJECUTOR DE ANÁLISIS AUTOMÁTICO FLAN
# ...
# 📊 Se encontraron 2 archivos JSON:
#   1. flan_results_10k.json (0.5 MB)
#   2. flan_resultsmega.json (5.1 MB)
#
# 🔍 Selecciona archivo (1-2, o Enter para el más reciente): 1
# 📈 Analizando: flan_results_10k.json
#
# 🔍 Ejecutando análisis avanzado...
# ✅ JSON cargado exitosamente: flan_results_10k.json
# 🎯 ANALIZADOR JSON AVANZADO - REPORTE COMPLETO
# ...
# 📊 ESTRUCTURA DEL JSON:
#   • Esquemas: 1
#   • Agentes: 2
#   • Métricas: 5
#
# �� DIAGNÓSTICO AUTOMÁTICO:
#   • Problemas críticos: 3
#   • Problemas moderados: 2
#   • Oportunidades: 0
#
# 🔴 PROBLEMAS CRÍTICOS DETECTADOS:
#   🔴 Fine_qlearning: Recompensa CRÍTICA (-81.6) - Necesita +56.6 puntos
#   🔴 Fine_qlearning: Supervivencia CRÍTICA (41.1 pasos) - Muere muy rápido
#   🔴 Fine_stochastic: Supervivencia CRÍTICA (40.1 pasos) - Muere muy rápido
#
# �� MEJORAS AUTOMÁTICAS GENERADAS:
#
# 📈 REWARD_SHAPING:
#   🔴 SUPERVIVENCIA CRÍTICA - Reward Shaping Ultra Agresivo:
# ...

# %%
# !cd descent_env/
# !python descent_env/verificacion_rapida.py
# Out:
# 🎯 VERIFICACIÓN RÁPIDA FLAN
# ...
# 🔥 Probando configuración antes del experimento completo
# ⏱️ Duración estimada: 2-3 minutos
#
# 🔍 PRUEBA 1: Importación BlueSky
# ----------------------------------------
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2025-07-04 16:40:51.031021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751647251.084809  222710 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751647251.102731  222710 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python ejecutar_experimento_express.py
# Out:
# 🎯 FLAN - EXPERIMENTO EXPRESS
# ...
# 🔥 DescentEnv REAL + Mejoras Automáticas (Versión Optimizada)
# 📈 OBJETIVO: Validar mejoras automáticas rápidamente
#
# 🖥️ INFORMACIÓN DEL SISTEMA
# ----------------------------------------
# CPU cores: 2 lógicos
# RAM disponible: 10.6 GB
#
# ⏱️ EXPERIMENTO EXPRESS - ESTIMACIÓN DE TIEMPO
# ...
# 📊 CONFIGURACIÓN EXPRESS:
#    • Hiperparámetros: 1,000 episodios por combinación
#    • Entrenamiento final: 5,000 episodios por agente
#    • Evaluación: 500 episodios por agente
#    • TOTAL: 23,000 episodios
#
# ⏰ TIEMPO ESTIMADO:
#    • Tiempo por episodio: 1.7 segundos
#    • Tiempo total: 10.9 horas
#    • Inicio: 04:15:43
#    • Finalización: 15:07:23
#    • Duración: 10:51:40
#
# 🚨 CONFIGURACIÓN EXPRESS
# ...
# • Entorno: DescentEnv REAL (BlueSky)
# • Mejoras: Automáticas integradas
# • Episodios: ~23,000 (vs 256,000 completo)
# • Tiempo: ~10.9 horas (vs 120+ completo)
# • Propósito: Validación científica rápida
#
# ¿Proceder con experimento EXPRESS? (y/N): y
# ...
